# %%
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
openai_client = OpenAI()

# %%
from rag_helper import RAGBase
from ingest import build_index,load_faq_data

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
assistant = RAGBase(index, openai_client)

# %%
assistant.rag("i have just discovered the course, can i join it?")
# Out:
# 'Yes, you can still join. If you want a certificate, make sure to submit your project while submissions are still open.'

# %% [markdown]
# # using sqlite search

# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
sqlite_index.search("i have just discovered the course, can i join it?")
# Out:
# []

# %%
assistant = RAGBase(sqlite_index, openai_client)

# %%
assistant.rag("i have just discovered the course, can i join it?")
# Out:
# "I don't know."
